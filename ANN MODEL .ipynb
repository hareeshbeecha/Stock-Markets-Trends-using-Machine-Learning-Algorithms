# %%
# Reading the cleaned numeric titanic survival data
import pandas as pd
import numpy as np
 
# To remove the scientific notation from numpy arrays
np.set_printoptions(suppress=True)
 
TitanicSurvivalDataNumeric=pd.read_pickle('TitanicSurvivalDataNumeric.pkl')
TitanicSurvivalDataNumeric.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0         0       3    1  22.0      1      0   7.2500           0           0
# 1         1       1    0  38.0      1      0  71.2833           1           0
# 2         1       3    0  26.0      0      0   7.9250           0           0
# 3         1       1    0  35.0      1      0  53.1000           0           0
# 4         0       3    1  35.0      0      0   8.0500           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
# Separate Target Variable and Predictor Variables
TargetVariable=['Survived']
Predictors=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Embarked_C', 'Embarked_Q', 'Embarked_S']

X=TitanicSurvivalDataNumeric[Predictors].values
y=TitanicSurvivalDataNumeric[TargetVariable].values


### Sandardization of data ###
### We does not standardize the Target variable for classification
from sklearn.preprocessing import StandardScaler
PredictorScaler=StandardScaler()

# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(X)

# Generating the standardized values of X and y
X=PredictorScalerFit.transform(X)

# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Quick sanity check with the shapes of Training and Testing datasets
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (623, 9)
# (623, 1)
# (268, 9)
# (268, 1)

# %%
classifier = Sequential()
# Defining the Input layer and FIRST hidden layer,both are same!
# relu means Rectifier linear unit function
classifier.add(Dense(units=10, input_dim=9, kernel_initializer='uniform', activation='relu'))

#Defining the SECOND hidden layer, here we have not defined input because it is
# second layer and it will get input as the output of first hidden layer
classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))

# Defining the Output layer
# sigmoid means sigmoid activation function
# for Multiclass classification the activation ='softmax'
# And output_dim will be equal to the number of factor levels
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# Optimizer== the algorithm of SGG to keep updating weights
# loss== the loss function to measure the accuracy
# metrics== the way we will compare the accuracy after each step of SGD
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# fitting the Neural Network on the training data
survivalANN_Model=classifier.fit(X_train,y_train, batch_size=10 , epochs=10, verbose=1)

# fitting the Neural Network on the training data
survivalANN_Model=classifier.fit(X_train,y_train, batch_size=10 , epochs=10, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 classifier = Sequential()
#       2 # Defining the Input layer and FIRST hidden layer,both are same!
#       3 # relu means Rectifier linear unit function
#       4 classifier.add(Dense(units=10, input_dim=9, kernel_initializer='uniform', activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
classifier = Sequential()
# Defining the Input layer and FIRST hidden layer,both are same!
# relu means Rectifier linear unit function
classifier.add(Dense(units=10, input_dim=9, kernel_initializer='uniform', activation='relu'))

#Defining the SECOND hidden layer, here we have not defined input because it is
# second layer and it will get input as the output of first hidden layer
classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))

# Defining the Output layer
# sigmoid means sigmoid activation function
# for Multiclass classification the activation ='softmax'
# And output_dim will be equal to the number of factor levels
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# Optimizer== the algorithm of SGG to keep updating weights
# loss== the loss function to measure the accuracy
# metrics== the way we will compare the accuracy after each step of SGD
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# fitting the Neural Network on the training data
survivalANN_Model=classifier.fit(X_train,y_train, batch_size=10 , epochs=10, verbose=1)

# fitting the Neural Network on the training data
survivalANN_Model=classifier.fit(X_train,y_train, batch_size=10 , epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 1s 1ms/step - loss: 0.6898 - accuracy: 0.6308
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6729 - accuracy: 0.6292
# Epoch 3/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6206 - accuracy: 0.6501
# Epoch 4/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.5553 - accuracy: 0.7576
# Epoch 5/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5103 - accuracy: 0.7978
# Epoch 6/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4857 - accuracy: 0.7913
# Epoch 7/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4720 - accuracy: 0.7994
# Epoch 8/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4634 - accuracy: 0.8090
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4570 - accuracy: 0.7994
# Epoch 10/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.8090
# Epoch 1/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4494 - accuracy: 0.8090
# Epoch 2/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.8058
# Epoch 3/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4428 - accuracy: 0.8106
# Epoch 4/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.8058
# Epoch 5/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4379 - accuracy: 0.8074
# Epoch 6/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.8138
# Epoch 7/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.8122
# Epoch 8/10
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4346 - accuracy: 0.8106
# Epoch 9/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.8074
# Epoch 10/10
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4304 - accuracy: 0.8138

# %%
# Defining a function for finding best hyperparameters
def FunctionFindBestParams(X_train, y_train):
    
    # Defining the list of hyper parameters to try
    TrialNumber=0
    batch_size_list=[5, 10, 15, 20]
    epoch_list=[5, 10, 50 ,100]
    
    import pandas as pd
    SearchResultsData=pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])
    
    for batch_size_trial in batch_size_list:
        for epochs_trial in epoch_list:
            TrialNumber+=1
            
            # Creating the classifier ANN model
            classifier = Sequential()
            classifier.add(Dense(units=10, input_dim=9, kernel_initializer='uniform', activation='relu'))
            classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))
            classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
            classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

            
            survivalANN_Model=classifier.fit(X_train,y_train, batch_size=batch_size_trial , epochs=epochs_trial, verbose=0)
            # Fetching the accuracy of the training
            Accuracy = survivalANN_Model.history['accuracy'][-1]
            
            # printing the results of the current iteration
            print(TrialNumber, 'Parameters:','batch_size:', batch_size_trial,'-', 'epochs:',epochs_trial, 'Accuracy:', Accuracy)
            
            SearchResultsData=SearchResultsData.append(pd.DataFrame(data=[[TrialNumber,
                            'batch_size'+str(batch_size_trial)+'-'+'epoch'+str(epochs_trial), Accuracy]],
                                                                    columns=['TrialNumber', 'Parameters', 'Accuracy'] ))
    return(SearchResultsData)

###############################################

# Calling the function
ResultsData=FunctionFindBestParams(X_train, y_train)
# Out:
# 1 Parameters: batch_size: 5 - epochs: 5 Accuracy: 0.8089887499809265
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 39
#      34     return(SearchResultsData)
#      36 ###############################################
#      37
#      38 # Calling the function
# ---> 39 ResultsData=FunctionFindBestParams(X_train, y_train)
#
# Cell In[7], line 31, in FunctionFindBestParams(X_train, y_train)
#      28         # printing the results of the current iteration
#      29         print(TrialNumber, 'Parameters:','batch_size:', batch_size_trial,'-', 'epochs:',epochs_trial, 'Accuracy:', Accuracy)
# ---> 31         SearchResultsData=SearchResultsData.append(pd.DataFrame(data=[[TrialNumber,
#      32                         'batch_size'+str(batch_size_trial)+'-'+'epoch'+str(epochs_trial), Accuracy]],
#      33                                                                 columns=['TrialNumber', 'Parameters', 'Accuracy'] ))
#      34 return(SearchResultsData)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# Initializing the SearchResultsData DataFrame
SearchResultsData = pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])

for batch_size_trial in batch_size_list:
    for epochs_trial in epoch_list:
        TrialNumber += 1

        # Creating the classifier ANN model
        classifier = Sequential()
        classifier.add(Dense(units=10, input_dim=9, kernel_initializer='uniform', activation='relu'))
        classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))
        classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
        classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

        survivalANN_Model = classifier.fit(X_train, y_train, batch_size=batch_size_trial, epochs=epochs_trial, verbose=0)
        # Fetching the accuracy of the training
        Accuracy = survivalANN_Model.history['accuracy'][-1]

        # printing the results of the current iteration
        print(TrialNumber, 'Parameters:', 'batch_size:', batch_size_trial, '-', 'epochs:', epochs_trial, 'Accuracy:', Accuracy)

        # Appending the results to the SearchResultsData DataFrame
        SearchResultsData = SearchResultsData.append(pd.DataFrame(data=[[TrialNumber,
                                                                         'batch_size' + str(batch_size_trial) + '-' + 'epoch' + str(
                                                                             epochs_trial), Accuracy]],
                                                                 columns=['TrialNumber', 'Parameters', 'Accuracy']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 # Initializing the SearchResultsData DataFrame
#       2 SearchResultsData = pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])
# ----> 4 for batch_size_trial in batch_size_list:
#       5     for epochs_trial in epoch_list:
#       6         TrialNumber += 1
#
# NameError: name 'batch_size_list' is not defined

# %%
# Define batch size and epoch lists
batch_size_list = [5, 10, 15, 20]
epoch_list = [5, 10, 50, 100]

# Calling the function with defined batch size and epoch lists
ResultsData = FunctionFindBestParams(X_train, y_train)
# Out:
# 1 Parameters: batch_size: 5 - epochs: 5 Accuracy: 0.8057785034179688
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       3 epoch_list = [5, 10, 50, 100]
#       5 # Calling the function with defined batch size and epoch lists
# ----> 6 ResultsData = FunctionFindBestParams(X_train, y_train)
#
# Cell In[7], line 31, in FunctionFindBestParams(X_train, y_train)
#      28         # printing the results of the current iteration
#      29         print(TrialNumber, 'Parameters:','batch_size:', batch_size_trial,'-', 'epochs:',epochs_trial, 'Accuracy:', Accuracy)
# ---> 31         SearchResultsData=SearchResultsData.append(pd.DataFrame(data=[[TrialNumber,
#      32                         'batch_size'+str(batch_size_trial)+'-'+'epoch'+str(epochs_trial), Accuracy]],
#      33                                                                 columns=['TrialNumber', 'Parameters', 'Accuracy'] ))
#      34 return(SearchResultsData)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# Initializing the SearchResultsData DataFrame
SearchResultsData = pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])

for batch_size_trial in batch_size_list:
    for epochs_trial in epoch_list:
        TrialNumber += 1

        # Creating the classifier ANN model
        classifier = Sequential()
        classifier.add(Dense(units=10, input_dim=9, kernel_initializer='uniform', activation='relu'))
        classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))
        classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
        classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

        survivalANN_Model = classifier.fit(X_train, y_train, batch_size=batch_size_trial, epochs=epochs_trial, verbose=0)
        # Fetching the accuracy of the training
        Accuracy = survivalANN_Model.history['accuracy'][-1]

        # printing the results of the current iteration
        print(TrialNumber, 'Parameters:', 'batch_size:', batch_size_trial, '-', 'epochs:', epochs_trial, 'Accuracy:', Accuracy)

        # Appending the results to the SearchResultsData DataFrame
        SearchResultsData = pd.concat([SearchResultsData, pd.DataFrame(data=[[TrialNumber,
                                                                             'batch_size' + str(batch_size_trial) + '-' + 'epoch' + str(
                                                                                 epochs_trial), Accuracy]],
                                                                     columns=['TrialNumber', 'Parameters', 'Accuracy'])], ignore_index=True)
# Out:
# 1 Parameters: batch_size: 5 - epochs: 5 Accuracy: 0.8009631037712097
# 2 Parameters: batch_size: 5 - epochs: 10 Accuracy: 0.8105939030647278
# 3 Parameters: batch_size: 5 - epochs: 50 Accuracy: 0.8443017601966858
# 4 Parameters: batch_size: 5 - epochs: 100 Accuracy: 0.841091513633728
# 5 Parameters: batch_size: 10 - epochs: 5 Accuracy: 0.8154093027114868
# 6 Parameters: batch_size: 10 - epochs: 10 Accuracy: 0.8089887499809265
# 7 Parameters: batch_size: 10 - epochs: 50 Accuracy: 0.8202247023582458
# 8 Parameters: batch_size: 10 - epochs: 100 Accuracy: 0.8539325594902039
# 9 Parameters: batch_size: 15 - epochs: 5 Accuracy: 0.7817014455795288
# 10 Parameters: batch_size: 15 - epochs: 10 Accuracy: 0.8105939030647278
# 11 Parameters: batch_size: 15 - epochs: 50 Accuracy: 0.8426966071128845
# 12 Parameters: batch_size: 15 - epochs: 100 Accuracy: 0.8539325594902039
# 13 Parameters: batch_size: 20 - epochs: 5 Accuracy: 0.6565008163452148
# 14 Parameters: batch_size: 20 - epochs: 10 Accuracy: 0.8186196088790894
# 15 Parameters: batch_size: 20 - epochs: 50 Accuracy: 0.8266452550888062
# 16 Parameters: batch_size: 20 - epochs: 100 Accuracy: 0.8523274660110474

# %%
# Initializing the SearchResultsData DataFrame
SearchResultsData = pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])

TrialNumber = 0  # Initialize TrialNumber variable

for batch_size_trial in batch_size_list:
    for epochs_trial in epoch_list:
        TrialNumber += 1

        # Creating the classifier ANN model
        classifier = Sequential()
        classifier.add(Dense(units=10, input_dim=9, kernel_initializer='uniform', activation='relu'))
        classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))
        classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
        classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

        survivalANN_Model = classifier.fit(X_train, y_train, batch_size=batch_size_trial, epochs=epochs_trial, verbose=0)
        # Fetching the accuracy of the training
        Accuracy = survivalANN_Model.history['accuracy'][-1]

        # printing the results of the current iteration
        print(TrialNumber, 'Parameters:', 'batch_size:', batch_size_trial, '-', 'epochs:', epochs_trial, 'Accuracy:', Accuracy)

        # Appending the results to the SearchResultsData DataFrame
        SearchResultsData = pd.concat([SearchResultsData, pd.DataFrame(data=[[TrialNumber,'batch_size' + str(batch_size_trial) + '-' + 'epoch' + str(epochs_trial), Accuracy]],columns=['TrialNumber', 'Parameters', 'Accuracy'])], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Initializing the SearchResultsData DataFrame
# ----> 2 SearchResultsData = pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])
#       4 TrialNumber = 0  # Initialize TrialNumber variable
#       6 for batch_size_trial in batch_size_list:
#
# NameError: name 'pd' is not defined

# %%
# Printing the best parameter
print(ResultsData.sort_values(by='Accuracy', ascending=False).head(1))

# Visualizing the results
# %matplotlib inline
ResultsData.plot(x='Parameters', y='Accuracy', figsize=(15,4), kind='line', rot=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Printing the best parameter
# ----> 2 print(ResultsData.sort_values(by='Accuracy', ascending=False).head(1))
#       4 # Visualizing the results
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# NameError: name 'ResultsData' is not defined

# %%
# Printing the best parameter
print(SearchResultsData.sort_values(by='Accuracy', ascending=False).head(1))

# Visualizing the results
# %matplotlib inline
SearchResultsData.plot(x='Parameters', y='Accuracy', figsize=(15,4), kind='line', rot=20)

# %%
# Training the model with best hyperparamters
classifier.fit(X_train,y_train, batch_size=5 , epochs=100, verbose=1)

# %%
# Predictions on testing data
Predictions=classifier.predict(X_test)

# Scaling the test data back to original scale
Test_Data=PredictorScalerFit.inverse_transform(X_test)

# Generating a data frame for analyzing the test data
TestingData=pd.DataFrame(data=Test_Data, columns=Predictors)
TestingData['Survival']=y_test
TestingData['PredictedSurvivalProb']=Predictions

# Defining the probability threshold
def probThreshold(inpProb):
    if inpProb  >  0.5:
        return(1)
    else:
        return(0)

# Generating predictions on the testing data by applying probability threshold
TestingData['PredictedSurvival']=TestingData['PredictedSurvivalProb'].apply(probThreshold)
print(TestingData.head())

###############################################
from sklearn import metrics
print('\n######### Testing Accuracy Results #########')
print(metrics.classification_report(TestingData['Survival'], TestingData['PredictedSurvival']))
print(metrics.confusion_matrix(TestingData['Survival'], TestingData['PredictedSurvival']))
# Out:
# 9/9 [==============================] - 0s 2ms/step
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0     3.0  1.0  23.0    1.0    1.0  15.2458         1.0         0.0
# 1     2.0  1.0  31.0    0.0    0.0  10.5000         0.0         0.0
# 2     3.0  1.0  20.0    0.0    0.0   7.9250         0.0         0.0
# 3     2.0  0.0   6.0    0.0    1.0  33.0000         0.0         0.0
# 4     3.0  0.0  14.0    1.0    0.0  11.2417         1.0         0.0
#
#    Embarked_S  Survival  PredictedSurvivalProb  PredictedSurvival
# 0         0.0         1               0.433230                  0
# 1         1.0         0               0.091742                  0
# 2         1.0         0               0.141025                  0
# 3         1.0         1               0.953139                  1
# 4         0.0         1               0.461659                  0
#
# ######### Testing Accuracy Results #########
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83       157
#            1       0.81      0.65      0.72       111
#
#     accuracy                           0.79       268
#    macro avg       0.80      0.77      0.78       268
# weighted avg       0.79      0.79      0.79       268
#
# [[140  17]
#  [ 39  72]]

# %%
# Function to generate Deep ANN model 
def make_classification_ann(Optimizer_Trial, Neurons_Trial):
    from keras.models import Sequential
    from keras.layers import Dense
    
    # Creating the classifier ANN model
    classifier = Sequential()
    classifier.add(Dense(units=Neurons_Trial, input_dim=9, kernel_initializer='uniform', activation='relu'))
    classifier.add(Dense(units=Neurons_Trial, kernel_initializer='uniform', activation='relu'))
    classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
    classifier.compile(optimizer=Optimizer_Trial, loss='binary_crossentropy', metrics=['accuracy'])
            
    return classifier

########################################

from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier


Parameter_Trials={'batch_size':[10,20,30],
                      'epochs':[10,20],
                    'Optimizer_Trial':['adam', 'rmsprop'],
                  'Neurons_Trial': [5,10]
                 }

# Creating the classifier ANN
classifierModel=KerasClassifier(make_classification_ann, verbose=0)

########################################

# Creating the Grid search space
# See different scoring methods by using sklearn.metrics.SCORERS.keys()
grid_search=GridSearchCV(estimator=classifierModel, param_grid=Parameter_Trials, scoring='f1', cv=5)

########################################

# Measuring how much time it took to find the best params
import time
StartTime=time.time()

# Running Grid Search for different paramenters
grid_search.fit(X_train,y_train, verbose=1)

EndTime=time.time()
print("############### Total Time Taken: ", round((EndTime-StartTime)/60), 'Minutes #############')

########################################

# printing the best parameters
print('\n#### Best hyperparamters ####')
grid_search.best_params_
# Out:
# C:\Users\srich\AppData\Local\Temp\ipykernel_15752\1686040440.py:28: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifierModel=KerasClassifier(make_classification_ann, verbose=0)
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6904 - accuracy: 0.6205
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.6265
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.6265
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6021 - accuracy: 0.6265
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5640 - accuracy: 0.6265
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.6265
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.6265
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5240 - accuracy: 0.6265
# Epoch 9/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5186 - accuracy: 0.6386
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5139 - accuracy: 0.8173
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 50/50 [==============================] - 1s 3ms/step - loss: 0.6907 - accuracy: 0.6386
# Epoch 2/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6813 - accuracy: 0.6365
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6553 - accuracy: 0.6365
# Epoch 4/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6121 - accuracy: 0.6365
# Epoch 5/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5736 - accuracy: 0.6486
# Epoch 6/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5516 - accuracy: 0.7269
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.7831
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5244 - accuracy: 0.7892
# Epoch 9/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.7992
# Epoch 10/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5030 - accuracy: 0.7952
# 4/4 [==============================] - 0s 4ms/step
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6910 - accuracy: 0.6104
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.6265
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6654 - accuracy: 0.6265
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6281 - accuracy: 0.6285
# Epoch 5/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.6948
# Epoch 6/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5447 - accuracy: 0.7610
# Epoch 7/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5158 - accuracy: 0.7912
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4933 - accuracy: 0.8052
# Epoch 9/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4776 - accuracy: 0.8133
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.8032
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.6333
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.6373
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6576 - accuracy: 0.6373
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6135 - accuracy: 0.6794
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5636 - accuracy: 0.7635
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5271 - accuracy: 0.8036
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.8417
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4847 - accuracy: 0.8417
# Epoch 9/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.8297
# Epoch 10/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4616 - accuracy: 0.8337
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6916 - accuracy: 0.6152
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.6192
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6736 - accuracy: 0.6192
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6394 - accuracy: 0.6253
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5935 - accuracy: 0.7234
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7615
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5291 - accuracy: 0.7876
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5088 - accuracy: 0.7896
# Epoch 9/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.7876
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.7856
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6910 - accuracy: 0.6185
# Epoch 2/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.6305
# Epoch 3/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6698 - accuracy: 0.7892
# Epoch 4/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.7811
# Epoch 5/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6121 - accuracy: 0.7851
# Epoch 6/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5899 - accuracy: 0.7892
# Epoch 7/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5729 - accuracy: 0.7972
# Epoch 8/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5594 - accuracy: 0.8052
# Epoch 9/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5476 - accuracy: 0.8092
# Epoch 10/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5388 - accuracy: 0.8092
# Epoch 11/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.8133
# Epoch 12/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5211 - accuracy: 0.8153
# Epoch 13/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5132 - accuracy: 0.8173
# Epoch 14/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5068 - accuracy: 0.8153
# Epoch 15/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.8173
# Epoch 16/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.8193
# Epoch 17/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4899 - accuracy: 0.8193
# Epoch 18/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.8153
# Epoch 19/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4810 - accuracy: 0.8193
# Epoch 20/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.8173
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.6365
# Epoch 2/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.6365
# Epoch 3/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6611 - accuracy: 0.6365
# Epoch 4/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6242 - accuracy: 0.6365
# Epoch 5/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.6406
# Epoch 6/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5560 - accuracy: 0.7209
# Epoch 7/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5341 - accuracy: 0.7731
# Epoch 8/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.7871
# Epoch 9/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7892
# Epoch 10/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.7932
# Epoch 11/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4882 - accuracy: 0.7932
# Epoch 12/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4830 - accuracy: 0.7892
# Epoch 13/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4792 - accuracy: 0.7912
# Epoch 14/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7871
# Epoch 15/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4739 - accuracy: 0.7892
# Epoch 16/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4717 - accuracy: 0.7851
# Epoch 17/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4691 - accuracy: 0.7851
# Epoch 18/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.7871
# Epoch 19/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7892
# Epoch 20/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4635 - accuracy: 0.7851
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/20
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6910 - accuracy: 0.6124
# Epoch 2/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.6265
# Epoch 3/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.6285
# Epoch 4/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6317 - accuracy: 0.7068
# Epoch 5/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5869 - accuracy: 0.7791
# Epoch 6/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.7992
# Epoch 7/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5084 - accuracy: 0.8092
# Epoch 8/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.8012
# Epoch 9/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4686 - accuracy: 0.7992
# Epoch 10/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.7992
# Epoch 11/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8052
# Epoch 12/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4461 - accuracy: 0.8012
# Epoch 13/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8072
# Epoch 14/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4404 - accuracy: 0.7992
# Epoch 15/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4374 - accuracy: 0.8032
# Epoch 16/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.7972
# Epoch 17/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.8012
# Epoch 18/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4327 - accuracy: 0.8012
# Epoch 19/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.8012
# Epoch 20/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.8072
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6911 - accuracy: 0.6232
# Epoch 2/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.6373
# Epoch 3/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6737 - accuracy: 0.6373
# Epoch 4/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6507 - accuracy: 0.6373
# Epoch 5/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6153 - accuracy: 0.7034
# Epoch 6/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5750 - accuracy: 0.7756
# Epoch 7/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5349 - accuracy: 0.8156
# Epoch 8/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.8277
# Epoch 9/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4740 - accuracy: 0.8297
# Epoch 10/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.8277
# Epoch 11/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.8216
# Epoch 12/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.8257
# Epoch 13/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 0.8317
# Epoch 14/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.8317
# Epoch 15/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.8357
# Epoch 16/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4295 - accuracy: 0.8357
# Epoch 17/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4278 - accuracy: 0.8337
# Epoch 18/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4257 - accuracy: 0.8397
# Epoch 19/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8377
# Epoch 20/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4234 - accuracy: 0.8337
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6915 - accuracy: 0.5992
# Epoch 2/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.6192
# Epoch 3/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6653 - accuracy: 0.6192
# Epoch 4/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6300 - accuracy: 0.6192
# Epoch 5/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5945 - accuracy: 0.6192
# Epoch 6/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5702 - accuracy: 0.6192
# Epoch 7/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5544 - accuracy: 0.6353
# Epoch 8/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7615
# Epoch 9/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5342 - accuracy: 0.8056
# Epoch 10/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5249 - accuracy: 0.8036
# Epoch 11/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5182 - accuracy: 0.7976
# Epoch 12/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5134 - accuracy: 0.7996
# Epoch 13/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5089 - accuracy: 0.7976
# Epoch 14/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5054 - accuracy: 0.7996
# Epoch 15/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.8036
# Epoch 16/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.8016
# Epoch 17/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.8036
# Epoch 18/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4924 - accuracy: 0.7996
# Epoch 19/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4887 - accuracy: 0.7996
# Epoch 20/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.7996
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6920 - accuracy: 0.6165
# Epoch 2/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.6265
# Epoch 3/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.6265
# Epoch 4/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6777 - accuracy: 0.6265
# Epoch 5/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6647 - accuracy: 0.6265
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6454 - accuracy: 0.6285
# Epoch 7/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6194 - accuracy: 0.6627
# Epoch 8/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5893 - accuracy: 0.7550
# Epoch 9/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5557 - accuracy: 0.7972
# Epoch 10/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5272 - accuracy: 0.8173
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6917 - accuracy: 0.6325
# Epoch 2/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.6365
# Epoch 3/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.6365
# Epoch 4/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.6365
# Epoch 5/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6631 - accuracy: 0.6365
# Epoch 6/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6462 - accuracy: 0.6365
# Epoch 7/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6240 - accuracy: 0.6446
# Epoch 8/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5989 - accuracy: 0.6948
# Epoch 9/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5743 - accuracy: 0.7209
# Epoch 10/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5553 - accuracy: 0.7490
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6920 - accuracy: 0.6265
# Epoch 2/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.6265
# Epoch 3/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.6265
# Epoch 4/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6690 - accuracy: 0.6265
# Epoch 5/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6479 - accuracy: 0.6265
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6199 - accuracy: 0.6265
# Epoch 7/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5912 - accuracy: 0.6386
# Epoch 8/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5655 - accuracy: 0.7209
# Epoch 9/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7550
# Epoch 10/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.7671
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6916 - accuracy: 0.6373
# Epoch 2/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.6373
# Epoch 3/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6811 - accuracy: 0.6373
# Epoch 4/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.6373
# Epoch 5/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6508 - accuracy: 0.6373
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6264 - accuracy: 0.6373
# Epoch 7/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5974 - accuracy: 0.6393
# Epoch 8/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5674 - accuracy: 0.7054
# Epoch 9/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5423 - accuracy: 0.7756
# Epoch 10/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5232 - accuracy: 0.8036
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6919 - accuracy: 0.6172
# Epoch 2/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.6192
# Epoch 3/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6858 - accuracy: 0.6433
# Epoch 4/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6794 - accuracy: 0.6954
# Epoch 5/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6692 - accuracy: 0.7856
# Epoch 6/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6554 - accuracy: 0.7776
# Epoch 7/10
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6390 - accuracy: 0.7595
# Epoch 8/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6252 - accuracy: 0.7495
# Epoch 9/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6123 - accuracy: 0.7535
# Epoch 10/10
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6025 - accuracy: 0.7595
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/20
# 25/25 [==============================] - 1s 3ms/step - loss: 0.6916 - accuracy: 0.6104
# Epoch 2/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.6265
# Epoch 3/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6841 - accuracy: 0.6265
# Epoch 4/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6764 - accuracy: 0.6285
# Epoch 5/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6623 - accuracy: 0.6767
# Epoch 6/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6408 - accuracy: 0.7550
# Epoch 7/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6124 - accuracy: 0.8052
# Epoch 8/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5804 - accuracy: 0.8112
# Epoch 9/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5465 - accuracy: 0.8153
# Epoch 10/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5146 - accuracy: 0.8153
# Epoch 11/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4881 - accuracy: 0.8112
# Epoch 12/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.8133
# Epoch 13/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4516 - accuracy: 0.8153
# Epoch 14/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.8133
# Epoch 15/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4335 - accuracy: 0.8133
# Epoch 16/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.8133
# Epoch 17/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4242 - accuracy: 0.8173
# Epoch 18/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4211 - accuracy: 0.8173
# Epoch 19/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4195 - accuracy: 0.8173
# Epoch 20/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4173 - accuracy: 0.8153
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6923 - accuracy: 0.5904
# Epoch 2/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.6365
# Epoch 3/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.6365
# Epoch 4/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.6365
# Epoch 5/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.6426
# Epoch 6/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6948
# Epoch 7/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6335 - accuracy: 0.7349
# Epoch 8/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6093 - accuracy: 0.7410
# Epoch 9/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5838 - accuracy: 0.7651
# Epoch 10/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5601 - accuracy: 0.7851
# Epoch 11/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.7912
# Epoch 12/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5213 - accuracy: 0.7932
# Epoch 13/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5094 - accuracy: 0.7912
# Epoch 14/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.7912
# Epoch 15/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4937 - accuracy: 0.7912
# Epoch 16/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4882 - accuracy: 0.7892
# Epoch 17/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4844 - accuracy: 0.7851
# Epoch 18/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.7932
# Epoch 19/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4796 - accuracy: 0.7952
# Epoch 20/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.7912
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 25/25 [==============================] - 1s 3ms/step - loss: 0.6915 - accuracy: 0.6225
# Epoch 2/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.6265
# Epoch 3/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.6265
# Epoch 4/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6823 - accuracy: 0.6345
# Epoch 5/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6758 - accuracy: 0.7229
# Epoch 6/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6664 - accuracy: 0.7771
# Epoch 7/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.7811
# Epoch 8/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6391 - accuracy: 0.7892
# Epoch 9/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6238 - accuracy: 0.7871
# Epoch 10/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6099 - accuracy: 0.7831
# Epoch 11/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.7831
# Epoch 12/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5877 - accuracy: 0.7892
# Epoch 13/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5789 - accuracy: 0.7912
# Epoch 14/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5708 - accuracy: 0.7972
# Epoch 15/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5640 - accuracy: 0.7972
# Epoch 16/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.7972
# Epoch 17/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5516 - accuracy: 0.7932
# Epoch 18/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5458 - accuracy: 0.7932
# Epoch 19/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7932
# Epoch 20/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5358 - accuracy: 0.7992
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/20
# 25/25 [==============================] - 1s 3ms/step - loss: 0.6917 - accuracy: 0.6212
# Epoch 2/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.6373
# Epoch 3/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.6373
# Epoch 4/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6825 - accuracy: 0.6373
# Epoch 5/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6780 - accuracy: 0.6413
# Epoch 6/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6712 - accuracy: 0.7174
# Epoch 7/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6628 - accuracy: 0.7515
# Epoch 8/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6516 - accuracy: 0.8076
# Epoch 9/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6390 - accuracy: 0.8216
# Epoch 10/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6265 - accuracy: 0.8236
# Epoch 11/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6121 - accuracy: 0.8236
# Epoch 12/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5999 - accuracy: 0.8257
# Epoch 13/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5880 - accuracy: 0.8216
# Epoch 14/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5771 - accuracy: 0.8216
# Epoch 15/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5676 - accuracy: 0.8236
# Epoch 16/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5594 - accuracy: 0.8176
# Epoch 17/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5512 - accuracy: 0.8216
# Epoch 18/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5442 - accuracy: 0.8216
# Epoch 19/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.8277
# Epoch 20/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5317 - accuracy: 0.8216
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/20
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6919 - accuracy: 0.6172
# Epoch 2/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.6192
# Epoch 3/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.6192
# Epoch 4/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6769 - accuracy: 0.6192
# Epoch 5/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6654 - accuracy: 0.6212
# Epoch 6/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6495 - accuracy: 0.6513
# Epoch 7/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6295 - accuracy: 0.7134
# Epoch 8/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6070 - accuracy: 0.7735
# Epoch 9/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5833 - accuracy: 0.7936
# Epoch 10/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5593 - accuracy: 0.8136
# Epoch 11/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.8136
# Epoch 12/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5191 - accuracy: 0.8096
# Epoch 13/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.8036
# Epoch 14/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4942 - accuracy: 0.7996
# Epoch 15/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4863 - accuracy: 0.8016
# Epoch 16/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.8016
# Epoch 17/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4756 - accuracy: 0.8056
# Epoch 18/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.8056
# Epoch 19/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4696 - accuracy: 0.8056
# Epoch 20/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4674 - accuracy: 0.8036
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6921 - accuracy: 0.6345
# Epoch 2/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.6265
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.6265
# Epoch 4/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.6265
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6736 - accuracy: 0.6265
# Epoch 6/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6620 - accuracy: 0.6265
# Epoch 7/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6448 - accuracy: 0.6265
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6255 - accuracy: 0.6285
# Epoch 9/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6025 - accuracy: 0.6586
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.7108
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6920 - accuracy: 0.6386
# Epoch 2/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.6365
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.6365
# Epoch 4/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6816 - accuracy: 0.6365
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.6365
# Epoch 6/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6634 - accuracy: 0.6365
# Epoch 7/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.6365
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.6365
# Epoch 9/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6132 - accuracy: 0.6365
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5972 - accuracy: 0.6365
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.6265
# Epoch 2/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.6265
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.6265
# Epoch 4/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.6265
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6712 - accuracy: 0.6265
# Epoch 6/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6571 - accuracy: 0.6265
# Epoch 7/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6397 - accuracy: 0.6265
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6182 - accuracy: 0.6265
# Epoch 9/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5961 - accuracy: 0.6265
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5764 - accuracy: 0.6265
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6923 - accuracy: 0.6072
# Epoch 2/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6900 - accuracy: 0.6373
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.6373
# Epoch 4/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6842 - accuracy: 0.6373
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.6373
# Epoch 6/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6730 - accuracy: 0.6393
# Epoch 7/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6643 - accuracy: 0.6493
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6527 - accuracy: 0.7094
# Epoch 9/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.7415
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6217 - accuracy: 0.7535
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6924 - accuracy: 0.6072
# Epoch 2/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.6192
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.6192
# Epoch 4/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.6192
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.6192
# Epoch 6/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.6192
# Epoch 7/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6677 - accuracy: 0.6192
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6573 - accuracy: 0.6212
# Epoch 9/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6446 - accuracy: 0.6313
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6300 - accuracy: 0.6894
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6921 - accuracy: 0.6205
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6900 - accuracy: 0.6265
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.6265
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.6265
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6787 - accuracy: 0.6265
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6712 - accuracy: 0.6265
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6609 - accuracy: 0.6265
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6467 - accuracy: 0.6265
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6291 - accuracy: 0.6265
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6094 - accuracy: 0.6566
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5866 - accuracy: 0.7771
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5650 - accuracy: 0.7952
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.8092
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5221 - accuracy: 0.8233
# Epoch 15/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5046 - accuracy: 0.8153
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.8213
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4746 - accuracy: 0.8173
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4625 - accuracy: 0.8173
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4535 - accuracy: 0.8153
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4460 - accuracy: 0.8133
# 4/4 [==============================] - 0s 4ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.6165
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.6365
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.6365
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.6365
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6808 - accuracy: 0.6586
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.7008
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6680 - accuracy: 0.7430
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6588 - accuracy: 0.7791
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6487 - accuracy: 0.7871
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6365 - accuracy: 0.7871
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6247 - accuracy: 0.7811
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6138 - accuracy: 0.7691
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.7811
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5949 - accuracy: 0.7791
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5861 - accuracy: 0.7791
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5783 - accuracy: 0.7831
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5708 - accuracy: 0.7831
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5634 - accuracy: 0.7811
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5572 - accuracy: 0.7831
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5502 - accuracy: 0.7831
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.6265
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.6265
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6870 - accuracy: 0.6265
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.6265
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6769 - accuracy: 0.6265
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6688 - accuracy: 0.6265
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6565 - accuracy: 0.6285
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6409 - accuracy: 0.6406
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6212 - accuracy: 0.7008
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5993 - accuracy: 0.7590
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5772 - accuracy: 0.7811
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5550 - accuracy: 0.7851
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5350 - accuracy: 0.7912
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5183 - accuracy: 0.7871
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.7972
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.8052
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4817 - accuracy: 0.8052
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.8072
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.8072
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.8072
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6923 - accuracy: 0.6092
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6898 - accuracy: 0.6373
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.6373
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6817 - accuracy: 0.6373
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6742 - accuracy: 0.6373
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6630 - accuracy: 0.6373
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6478 - accuracy: 0.6673
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6287 - accuracy: 0.7315
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6064 - accuracy: 0.7495
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5831 - accuracy: 0.7735
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5603 - accuracy: 0.7856
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7876
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.8056
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5024 - accuracy: 0.8216
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4891 - accuracy: 0.8277
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4776 - accuracy: 0.8277
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.8297
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4596 - accuracy: 0.8277
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4533 - accuracy: 0.8196
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.8297
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.6212
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.6192
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.6192
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.6192
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.6212
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6709 - accuracy: 0.6493
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6602 - accuracy: 0.7094
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.7475
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6299 - accuracy: 0.7836
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6100 - accuracy: 0.8016
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.7936
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5680 - accuracy: 0.7956
# Epoch 13/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5484 - accuracy: 0.7956
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5316 - accuracy: 0.7956
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5168 - accuracy: 0.7956
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.7996
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4945 - accuracy: 0.7956
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.7956
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.7936
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4759 - accuracy: 0.7936
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6888 - accuracy: 0.6185
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.6265
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6533 - accuracy: 0.6265
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6230 - accuracy: 0.6265
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.6265
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.6265
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5469 - accuracy: 0.6265
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.6265
# Epoch 9/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5226 - accuracy: 0.6667
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5131 - accuracy: 0.8032
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6898 - accuracy: 0.6345
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.6365
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6677 - accuracy: 0.6365
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6478 - accuracy: 0.6365
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6265 - accuracy: 0.6365
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6055 - accuracy: 0.6365
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5862 - accuracy: 0.6365
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.6365
# Epoch 9/10
# ...
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6655 - accuracy: 0.6365
# Epoch 6/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6536 - accuracy: 0.6386
# Epoch 7/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6404 - accuracy: 0.6586
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6262 - accuracy: 0.7088
# Epoch 9/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6106 - accuracy: 0.7229
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5945 - accuracy: 0.7329
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6911 - accuracy: 0.6044
# Epoch 2/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6858 - accuracy: 0.6265
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6782 - accuracy: 0.6265
# Epoch 4/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.6265
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6406
# Epoch 6/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6367 - accuracy: 0.6888
# Epoch 7/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6184 - accuracy: 0.7289
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5994 - accuracy: 0.7470
# Epoch 9/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5793 - accuracy: 0.7530
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5605 - accuracy: 0.7570
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6912 - accuracy: 0.6273
# Epoch 2/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.6373
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.6373
# Epoch 4/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6684 - accuracy: 0.6373
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6541 - accuracy: 0.6373
# Epoch 6/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6354 - accuracy: 0.6373
# Epoch 7/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6155 - accuracy: 0.6373
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5956 - accuracy: 0.6373
# Epoch 9/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.6453
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5594 - accuracy: 0.6774
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6909 - accuracy: 0.6273
# Epoch 2/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.6192
# Epoch 3/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6756 - accuracy: 0.6192
# Epoch 4/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6619 - accuracy: 0.6192
# Epoch 5/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6452 - accuracy: 0.6212
# Epoch 6/10
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6269 - accuracy: 0.6232
# Epoch 7/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6075 - accuracy: 0.6573
# Epoch 8/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5884 - accuracy: 0.7054
# Epoch 9/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5712 - accuracy: 0.7335
# Epoch 10/10
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5578 - accuracy: 0.7615
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6919 - accuracy: 0.5964
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.6265
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6826 - accuracy: 0.6305
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.6546
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6615 - accuracy: 0.7088
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.7289
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6282 - accuracy: 0.7570
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6079 - accuracy: 0.7811
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5861 - accuracy: 0.7851
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.8012
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.8072
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5207 - accuracy: 0.8072
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5021 - accuracy: 0.8112
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4860 - accuracy: 0.8092
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.8112
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.8092
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.8112
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4453 - accuracy: 0.8153
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4391 - accuracy: 0.8112
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.8052
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.6365
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.6365
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6726 - accuracy: 0.6365
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6593 - accuracy: 0.6365
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.6365
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6254 - accuracy: 0.6365
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6076 - accuracy: 0.6365
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5916 - accuracy: 0.6365
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5779 - accuracy: 0.6386
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5668 - accuracy: 0.6486
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5569 - accuracy: 0.6928
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5489 - accuracy: 0.7169
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.7309
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5368 - accuracy: 0.7369
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5320 - accuracy: 0.7751
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.7771
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5233 - accuracy: 0.7831
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5200 - accuracy: 0.7811
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5172 - accuracy: 0.7831
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5138 - accuracy: 0.7851
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6910 - accuracy: 0.6285
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.6265
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.6466
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6741 - accuracy: 0.7329
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6635 - accuracy: 0.7550
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.7691
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6360 - accuracy: 0.7691
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6182 - accuracy: 0.7771
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5986 - accuracy: 0.7831
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5781 - accuracy: 0.7871
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5576 - accuracy: 0.7932
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5392 - accuracy: 0.7912
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5211 - accuracy: 0.7932
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7972
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4897 - accuracy: 0.7912
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4769 - accuracy: 0.7972
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.7972
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4574 - accuracy: 0.7952
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.7952
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4452 - accuracy: 0.8012
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 2ms/step - loss: 0.6909 - accuracy: 0.6273
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.6373
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6781 - accuracy: 0.6373
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6668 - accuracy: 0.6373
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6525 - accuracy: 0.6553
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6354 - accuracy: 0.7014
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6166 - accuracy: 0.7234
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5968 - accuracy: 0.7455
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5766 - accuracy: 0.7675
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5567 - accuracy: 0.7695
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.7856
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5219 - accuracy: 0.8016
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5075 - accuracy: 0.8136
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.8216
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4843 - accuracy: 0.8277
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.8277
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4677 - accuracy: 0.8337
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.8337
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4557 - accuracy: 0.8317
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4506 - accuracy: 0.8317
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/20
# 17/17 [==============================] - 1s 3ms/step - loss: 0.6917 - accuracy: 0.5912
# Epoch 2/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.6192
# Epoch 3/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6827 - accuracy: 0.6192
# Epoch 4/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6748 - accuracy: 0.6192
# Epoch 5/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6643 - accuracy: 0.6192
# Epoch 6/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6523 - accuracy: 0.6232
# Epoch 7/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6386 - accuracy: 0.6473
# Epoch 8/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6237 - accuracy: 0.6974
# Epoch 9/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6081 - accuracy: 0.7275
# Epoch 10/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5931 - accuracy: 0.7395
# Epoch 11/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5777 - accuracy: 0.7495
# Epoch 12/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5634 - accuracy: 0.7695
# Epoch 13/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5510 - accuracy: 0.7695
# Epoch 14/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5404 - accuracy: 0.7776
# Epoch 15/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.7796
# Epoch 16/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5228 - accuracy: 0.7916
# Epoch 17/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5154 - accuracy: 0.7876
# Epoch 18/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5083 - accuracy: 0.7956
# Epoch 19/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7976
# Epoch 20/20
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4974 - accuracy: 0.7996
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/20
# 21/21 [==============================] - 1s 2ms/step - loss: 0.6921 - accuracy: 0.6164
# Epoch 2/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.6292
# Epoch 3/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.6292
# Epoch 4/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.6292
# Epoch 5/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6686 - accuracy: 0.6292
# Epoch 6/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6292
# Epoch 7/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6340 - accuracy: 0.6388
# Epoch 8/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 0.6998
# Epoch 9/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5877 - accuracy: 0.7496
# Epoch 10/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5637 - accuracy: 0.7801
# Epoch 11/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5435 - accuracy: 0.7994
# Epoch 12/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5255 - accuracy: 0.8058
# Epoch 13/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5108 - accuracy: 0.8090
# Epoch 14/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4992 - accuracy: 0.8154
# Epoch 15/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4894 - accuracy: 0.8170
# Epoch 16/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.8170
# Epoch 17/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4743 - accuracy: 0.8042
# Epoch 18/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4689 - accuracy: 0.8074
# Epoch 19/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.8058
# Epoch 20/20
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4605 - accuracy: 0.8042
# ############### Total Time Taken:  5 Minutes #############
#
# #### Best hyperparamters ####
# {'Neurons_Trial': 5, 'Optimizer_Trial': 'adam', 'batch_size': 30, 'epochs': 20}

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 from sklearn.metrics import classification_report
# ----> 3 print(classification_report(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
# Assuming you have already trained your model and stored it in 'classifier' variable

# Make predictions on the test set
y_pred = classifier.predict(X_test)

# Convert predicted probabilities to binary values (0 or 1)
y_pred_binary = (y_pred > 0.5).astype(int)

# Print the classification report
print(classification_report(y_test, y_pred_binary))
# Out:
# 9/9 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83       157
#            1       0.81      0.65      0.72       111
#
#     accuracy                           0.79       268
#    macro avg       0.80      0.77      0.78       268
# weighted avg       0.79      0.79      0.79       268
